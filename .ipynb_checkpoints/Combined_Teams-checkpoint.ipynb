# %% [markdown]
# <h2>All years to different files</h2>

# %% [markdown]
# <h2>All years together</h2>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
combined = pd.concat([ODI_df, T20I_df, TEST_df], ignore_index=True)

# %%
combined
# Out:
#       Year        Team 1       Team 2      Winner 3          Margin  \
# 0     2010    Bangladesh    Sri Lanka     Sri Lanka       7 wickets
# 1     2010         India    Sri Lanka     Sri Lanka       5 wickets
# 2     2010    Bangladesh        India         India       6 wickets
# 3     2010    Bangladesh    Sri Lanka     Sri Lanka       9 wickets
# 4     2010         India    Sri Lanka         India       8 wickets
# ...    ...           ...          ...           ...             ...
# 4085  2023         India    Australia     Australia       9 wickets
# 4086  2023  South Africa  West Indies  South Africa        284 runs
# 4087  2023   New Zealand    Sri Lanka   New Zealand       2 wickets
# 4088  2023         India    Australia         drawn
# 4089  2023   New Zealand    Sri Lanka   New Zealand  inns & 58 runs
#
#             Ground       Match_Date ScoreCard Text  \
# 0           Mirpur      Jan 4, 2010     ODI # 2937
# 1           Mirpur      Jan 5, 2010     ODI # 2938
# ...

# %%
combined.to_csv('Combined_Teams.csv', index=False)

# %%
# ODI
# create a list of year values for which you want to scrape data
year_list = [2010,2011,2012,2013,2014,2015,2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# create an empty DataFrame to store the combined data
ODI_df = pd.DataFrame(columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

# loop over the year values
for year in year_list:
    # generate the URL for the current year
    url = f'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=2;id={year};type=year'

    # send a request to the URL and get the response
    response = requests.get(url)

    # create a BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')

    # find the table you want to extract data from
    table = soup.find('table')

    # extract the table data
    table_data = []
    for row in table.find('tbody').find_all('tr'):
        row_data = []
        for i, cell in enumerate(row.find_all('td')):
            # check if this is the 7th column
            if i == 6:
                # get the hyperlink text and URL
                hyperlink = cell.find('a')
                if hyperlink:
                    row_data.append(hyperlink.text)
                    row_data.append(hyperlink['href'])
                else:
                    row_data.append('')
                    row_data.append('')
            else:
                row_data.append(cell.text)
        row_data.insert(0, year)  # insert the year value as the first column
        table_data.append(row_data)

    # create a pandas DataFrame to store the data for the current year
    df = pd.DataFrame(table_data, columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

    # append the data for the current year to the combined DataFrame
    ODI_df = pd.concat([ODI_df, df], ignore_index=True)

# export the combined DataFrame to a CSV file
#combined_df.to_csv('all_years.csv', index=False)

# %%
ODI_df
# Out:
#       Year        Team 1       Team 2      Winner 3     Margin    Ground  \
# 0     2010    Bangladesh    Sri Lanka     Sri Lanka  7 wickets    Mirpur
# 1     2010         India    Sri Lanka     Sri Lanka  5 wickets    Mirpur
# 2     2010    Bangladesh        India         India  6 wickets    Mirpur
# 3     2010    Bangladesh    Sri Lanka     Sri Lanka  9 wickets    Mirpur
# 4     2010         India    Sri Lanka         India  8 wickets    Mirpur
# ...    ...           ...          ...           ...        ...       ...
# 1617  2023       Namibia       P.N.G.       Namibia    48 runs  Windhoek
# 1618  2023       Namibia       Jersey       Namibia  8 wickets  Windhoek
# 1619  2023        U.A.E.       U.S.A.        U.S.A.  5 wickets  Windhoek
# 1620  2023   New Zealand    Sri Lanka   New Zealand  6 wickets  Hamilton
# 1621  2023  South Africa  Netherlands  South Africa  8 wickets    Benoni
#
#         Match_Date ScoreCard Text                  ScoreCard URL Format
# ...

# %%
ODI_df['Format'] = 'ODI'

# %%
# export the combined dataframe to a CSV file
ODI_df.to_csv('ODITeams.csv', index=False)

# %%
# T20I
# create a list of year values for which you want to scrape data
year_list = [2010,2011,2012,2013,2014,2015,2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# create an empty DataFrame to store the combined data
T20I_df = pd.DataFrame(columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

# loop over the year values
for year in year_list:
    # generate the URL for the current year
    url = f'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=3;id={year};type=year'

    # send a request to the URL and get the response
    response = requests.get(url)

    # create a BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')

    # find the table you want to extract data from
    table = soup.find('table')

    # extract the table data
    table_data = []
    for row in table.find('tbody').find_all('tr'):
        row_data = []
        for i, cell in enumerate(row.find_all('td')):
            # check if this is the 7th column
            if i == 6:
                # get the hyperlink text and URL
                hyperlink = cell.find('a')
                if hyperlink:
                    row_data.append(hyperlink.text)
                    row_data.append(hyperlink['href'])
                else:
                    row_data.append('')
                    row_data.append('')
            else:
                row_data.append(cell.text)
        row_data.insert(0, year)  # insert the year value as the first column
        table_data.append(row_data)

    # create a pandas DataFrame to store the data for the current year
    df = pd.DataFrame(table_data, columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

    # append the data for the current year to the combined DataFrame
    T20I_df = pd.concat([T20I_df, df], ignore_index=True)

# export the combined DataFrame to a CSV file
#combined_df.to_csv('all_years.csv', index=False)

# %%
T20I_df
# Out:
#       Year        Team 1       Team 2     Winner 3      Margin         Ground  \
# 0     2010   Afghanistan      Ireland      Ireland   5 wickets  Colombo (PSS)
# 1     2010         Kenya     Scotland        Kenya  10 wickets  Nairobi (Gym)
# 2     2010        Canada      Ireland       Canada      4 runs  Colombo (SSC)
# 3     2010   New Zealand   Bangladesh  New Zealand  10 wickets       Hamilton
# 4     2010   Afghanistan       Canada  Afghanistan   5 wickets  Colombo (SSC)
# ...    ...           ...          ...          ...         ...            ...
# 1906  2023    Bangladesh      Ireland   Bangladesh     22 runs     Chattogram
# 1907  2023   Afghanistan     Pakistan     Pakistan     66 runs        Sharjah
# 1908  2023  South Africa  West Indies  West Indies      7 runs   Johannesburg
# 1909  2023    Bangladesh      Ireland   Bangladesh     77 runs     Chattogram
# 1910  2023    Bangladesh      Ireland      Ireland   7 wickets     Chattogram
#
# ...

# %%
T20I_df['Format'] = 'T20I'

# %%
# export the combined DataFrame to a CSV file
T20I_df.to_csv('T20ITeams.csv', index=False)

# %%
# TEST
# create a list of year values for which you want to scrape data
year_list = [2010,2011,2012,2013,2014,2015,2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# create an empty DataFrame to store the combined data
TEST_df = pd.DataFrame(columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

# loop over the year values
for year in year_list:
    # generate the URL for the current year
    url = f'https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?class=1;id={year};type=year'

    # send a request to the URL and get the response
    response = requests.get(url)

    # create a BeautifulSoup object
    soup = BeautifulSoup(response.text, 'html.parser')

    # find the table you want to extract data from
    table = soup.find('table')

    # extract the table data
    table_data = []
    for row in table.find('tbody').find_all('tr'):
        row_data = []
        for i, cell in enumerate(row.find_all('td')):
            # check if this is the 7th column
            if i == 6:
                # get the hyperlink text and URL
                hyperlink = cell.find('a')
                if hyperlink:
                    row_data.append(hyperlink.text)
                    row_data.append(hyperlink['href'])
                else:
                    row_data.append('')
                    row_data.append('')
            else:
                row_data.append(cell.text)
        row_data.insert(0, year)  # insert the year value as the first column
        table_data.append(row_data)

    # create a pandas DataFrame to store the data for the current year
    df = pd.DataFrame(table_data, columns=['Year', 'Team 1', 'Team 2', 'Winner 3', 'Margin', 'Ground', 'Match_Date', 'ScoreCard Text', 'ScoreCard URL'])

    # append the data for the current year to the combined DataFrame
    TEST_df = pd.concat([TEST_df, df], ignore_index=True)

# export the combined DataFrame to a CSV file
#combined_df.to_csv('all_years.csv', index=False)

# %%
TEST_df
# Out:
#      Year        Team 1       Team 2      Winner 3          Margin  \
# 0    2010     Australia     Pakistan     Australia         36 runs
# 1    2010  South Africa      England         drawn
# 2    2010     Australia     Pakistan     Australia        231 runs
# 3    2010  South Africa      England  South Africa  inns & 74 runs
# 4    2010    Bangladesh        India         India        113 runs
# ..    ...           ...          ...           ...             ...
# 552  2023         India    Australia     Australia       9 wickets
# 553  2023  South Africa  West Indies  South Africa        284 runs
# 554  2023   New Zealand    Sri Lanka   New Zealand       2 wickets
# 555  2023         India    Australia         drawn
# 556  2023   New Zealand    Sri Lanka   New Zealand  inns & 58 runs
#
#            Ground       Match_Date ScoreCard Text  \
# 0          Sydney    Jan 3-6, 2010    Test # 1945
# 1       Cape Town    Jan 3-7, 2010    Test # 1946
# ...

# %%
TEST_df['Format'] = 'Test'

# %%
# export the combined DataFrame to a CSV file
TEST_df.to_csv('TestTeams.csv', index=False)
